# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Apple = yf.download("AAPL", start="2010-01-01", end="2021-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Apple.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-01-04  7.622500  7.660714  7.585000  7.643214   6.461977  493729600
# 2010-01-05  7.664286  7.699643  7.616071  7.656429   6.473148  601904800
# 2010-01-06  7.656429  7.686786  7.526786  7.534643   6.370183  552160000
# 2010-01-07  7.562500  7.571429  7.466071  7.520714   6.358408  477131200
# 2010-01-08  7.510714  7.571429  7.466429  7.570714   6.400681  447610800

# %%
ticker = ["SPY", "AAPL", "KO"]

# %%
stocks = yf.download(ticker, start = "2010-01-01", end = "2021-01-01")
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
stocks.head
# Out:
# <bound method NDFrame.head of Price        Adj Close                              Close             \
# Ticker            AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.461977  18.209932   86.580750    7.643214  28.520000
# 2010-01-05    6.473148  17.989649   86.809937    7.656429  28.174999
# 2010-01-06    6.370183  17.983267   86.871048    7.534643  28.165001
# 2010-01-07    6.358408  17.938576   87.237747    7.520714  28.094999
# 2010-01-08    6.400681  17.606556   87.528069    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.339020  48.019436  350.743164  131.970001  53.439999
# 2020-12-28  133.964935  48.666397  353.756348  136.690002  54.160000
# 2020-12-29  132.181229  48.639446  353.081482  134.869995  54.130001
# 2020-12-30  131.054169  48.918007  353.585205  133.720001  54.439999
# 2020-12-31  130.044693  49.277431  355.381775  132.690002  54.840000
#
# ...

# %%
stocks.to_csv("stocksYT.csv")

# %%
stocks = pd.read_csv("stocksYT.csv")

# %%
stocks
# Out:
#            Price           Adj Close         Adj Close.1         Adj Close.2  \
# 0         Ticker                AAPL                  KO                 SPY
# 1           Date                 NaN                 NaN                 NaN
# 2     2010-01-04   6.461977005004883  18.209932327270508   86.58074951171875
# 3     2010-01-05   6.473147869110107  17.989648818969727    86.8099365234375
# 4     2010-01-06   6.370182514190674  17.983266830444336   86.87104797363281
# ...          ...                 ...                 ...                 ...
# 2766  2020-12-24  129.33901977539062   48.01943588256836      350.7431640625
# 2767  2020-12-28  133.96493530273438   48.66639709472656     353.75634765625
# 2768  2020-12-29   132.1812286376953   48.63944625854492  353.08148193359375
# 2769  2020-12-30  131.05416870117188  48.918006896972656    353.585205078125
# 2770  2020-12-31  130.04469299316406   49.27743148803711  355.38177490234375
#
# ...

# %%
stocks = pd.read_csv("stocksYT.csv", header=[0,1])
stocks
# Out:
#            Price   Adj Close                              Close             \
#           Ticker        AAPL         KO         SPY        AAPL         KO
# 0           Date         NaN        NaN         NaN         NaN        NaN
# 1     2010-01-04    6.461977  18.209932   86.580750    7.643214  28.520000
# 2     2010-01-05    6.473148  17.989649   86.809937    7.656429  28.174999
# 3     2010-01-06    6.370183  17.983267   86.871048    7.534643  28.165001
# 4     2010-01-07    6.358408  17.938576   87.237747    7.520714  28.094999
# ...          ...         ...        ...         ...         ...        ...
# 2765  2020-12-24  129.339020  48.019436  350.743164  131.970001  53.439999
# 2766  2020-12-28  133.964935  48.666397  353.756348  136.690002  54.160000
# 2767  2020-12-29  132.181229  48.639446  353.081482  134.869995  54.130001
# 2768  2020-12-30  131.054169  48.918007  353.585205  133.720001  54.439999
# ...

# %%
stocks = pd.read_csv("stocksYT.csv", header=[0,1], index_col = [0], parse_dates=[0])
stocks
# Out:
# Price        Adj Close                              Close             \
# Ticker            AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.461977  18.209932   86.580750    7.643214  28.520000
# 2010-01-05    6.473148  17.989649   86.809937    7.656429  28.174999
# 2010-01-06    6.370183  17.983267   86.871048    7.534643  28.165001
# 2010-01-07    6.358408  17.938576   87.237747    7.520714  28.094999
# 2010-01-08    6.400681  17.606556   87.528069    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.339020  48.019436  350.743164  131.970001  53.439999
# 2020-12-28  133.964935  48.666397  353.756348  136.690002  54.160000
# 2020-12-29  132.181229  48.639446  353.081482  134.869995  54.130001
# 2020-12-30  131.054169  48.918007  353.585205  133.720001  54.439999
# 2020-12-31  130.044693  49.277431  355.381775  132.690002  54.840000
#
# ...

# %%
#convert multi index to one tuple
stocks.columns = stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'KO'),  ('Adj Close', 'SPY'),
#            ('Close', 'AAPL'),       ('Close', 'KO'),      ('Close', 'SPY'),
#             ('High', 'AAPL'),        ('High', 'KO'),       ('High', 'SPY'),
#              ('Low', 'AAPL'),         ('Low', 'KO'),        ('Low', 'SPY'),
#             ('Open', 'AAPL'),        ('Open', 'KO'),       ('Open', 'SPY'),
#           ('Volume', 'AAPL'),      ('Volume', 'KO'),     ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks
# Out:
#             (Adj Close, AAPL)  (Adj Close, KO)  (Adj Close, SPY)  \
# Date
# 2010-01-04           6.461977        18.209932         86.580750
# 2010-01-05           6.473148        17.989649         86.809937
# 2010-01-06           6.370183        17.983267         86.871048
# 2010-01-07           6.358408        17.938576         87.237747
# 2010-01-08           6.400681        17.606556         87.528069
# ...                       ...              ...               ...
# 2020-12-24         129.339020        48.019436        350.743164
# 2020-12-28         133.964935        48.666397        353.756348
# 2020-12-29         132.181229        48.639446        353.081482
# 2020-12-30         131.054169        48.918007        353.585205
# 2020-12-31         130.044693        49.277431        355.381775
#
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2010-01-04       7.643214    28.520000    113.330002      7.660714
# ...

# %%
stocks.columns=pd.MultiIndex.from_tuples(stocks.columns)
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.461977  18.209932   86.580750    7.643214  28.520000
# 2010-01-05    6.473148  17.989649   86.809937    7.656429  28.174999
# 2010-01-06    6.370183  17.983267   86.871048    7.534643  28.165001
# 2010-01-07    6.358408  17.938576   87.237747    7.520714  28.094999
# 2010-01-08    6.400681  17.606556   87.528069    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.339020  48.019436  350.743164  131.970001  53.439999
# 2020-12-28  133.964935  48.666397  353.756348  136.690002  54.160000
# 2020-12-29  132.181229  48.639446  353.081482  134.869995  54.130001
# 2020-12-30  131.054169  48.918007  353.585205  133.720001  54.439999
# 2020-12-31  130.044693  49.277431  355.381775  132.690002  54.840000
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
stocks.describe()
# Out:
#          Adj Close                                  Close               \
#               AAPL           KO          SPY         AAPL           KO
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# mean     31.479645    31.707147   180.904857    33.777537    41.320121
# std      24.550125     8.056273    69.264220    24.572747     6.808527
# min       5.798899    16.118818    78.772270     6.858929    25.014999
# 25%      15.161382    26.191204   114.157104    17.484285    37.660000
# 50%      24.484758    31.274151   174.871796    26.987499    41.759998
# 75%      40.824100    37.042484   240.407791    43.007500    45.549999
# max     133.964935    52.243053   355.381775   136.690002    60.130001
#
#                            High                                    Low  \
#                SPY         AAPL           KO          SPY         AAPL
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# ...

# %%
close = stocks.loc[:,"Close"].copy()

# %%
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# 2010-01-08    7.570714  27.575001  114.570000
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2769 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
#plt.style.use("seaborn-v0_8")

# %%
# Create a figure and axes
fig, ax = plt.subplots(figsize=(10, 6))  # Adjust figsize as needed

# Plot each column
ax.plot(close.index, close['AAPL'], label='AAPL')  # Assuming 'Date' is the index
ax.plot(close.index, close['KO'], label='KO')
ax.plot(close.index, close['SPY'], label='SPY')

# Customize plot
ax.set_xlabel('Date')
ax.set_ylabel('Price')
ax.set_title('Stock Prices')
ax.legend()

# Rotate x-axis labels for better readability (optional)
plt.xticks(rotation=45)

# Display plot
plt.tight_layout()  # Ensures all labels fit in the plot area
plt.show()

# %%
close.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
close.iloc[0,0]
#gets first value of first value
#iloc is used when we pass row and column in terms of number
#loc is used when we pass row and column in terms of the row/col name
# Out:
# 7.643214225769043

# %%
close.AAPL
# Out:
# Date
# 2010-01-04      7.643214
# 2010-01-05      7.656429
# 2010-01-06      7.534643
# 2010-01-07      7.520714
# 2010-01-08      7.570714
#                  ...
# 2020-12-24    131.970001
# 2020-12-28    136.690002
# 2020-12-29    134.869995
# 2020-12-30    133.720001
# 2020-12-31    132.690002
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0])
# Out:
# Date
# 2010-01-04     1.000000
# 2010-01-05     1.001729
# 2010-01-06     0.985795
# 2010-01-07     0.983973
# 2010-01-08     0.990514
#                 ...
# 2020-12-24    17.266296
# 2020-12-28    17.883838
# 2020-12-29    17.645717
# 2020-12-30    17.495258
# 2020-12-31    17.360498
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2010-01-04     100.000000
# 2010-01-05     100.172893
# 2010-01-06      98.579511
# 2010-01-07      98.397266
# 2010-01-08      99.051443
#                  ...
# 2020-12-24    1726.629626
# 2020-12-28    1788.383766
# 2020-12-29    1764.571699
# 2020-12-30    1749.525753
# 2020-12-31    1736.049763
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL      7.643214
# KO       28.520000
# SPY     113.330002
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
close.div(close.iloc[0]).mul(100)
# Out:
#                    AAPL          KO         SPY
# Date
# 2010-01-04   100.000000  100.000000  100.000000
# 2010-01-05   100.172893   98.790318  100.264710
# 2010-01-06    98.579511   98.755261  100.335302
# 2010-01-07    98.397266   98.509814  100.758846
# 2010-01-08    99.051443   96.686537  101.094148
# ...                 ...         ...         ...
# 2020-12-24  1726.629626  187.377271  325.597806
# 2020-12-28  1788.383766  189.901820  328.394959
# 2020-12-29  1764.571699  189.796635  327.768451
# 2020-12-30  1749.525753  190.883583  328.236111
# 2020-12-31  1736.049763  192.286112  329.903820
#
# [2769 rows x 3 columns]

# %%
normclose = close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
aapl = close.AAPL.copy().to_frame()

# %%
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2769 rows x 1 columns]

# %%
aapl.shift(periods=1)
#shifts the data
# Out:
#                   AAPL
# Date
# 2010-01-04         NaN
# 2010-01-05    7.643214
# 2010-01-06    7.656429
# 2010-01-07    7.534643
# 2010-01-08    7.520714
# ...                ...
# 2020-12-24  130.960007
# 2020-12-28  131.970001
# 2020-12-29  136.690002
# 2020-12-30  134.869995
# 2020-12-31  133.720001
#
# [2769 rows x 1 columns]

# %%
aapl["lag1"] = aapl.shift(periods=1)
#Adding a new column lag1 which has data that has been shifted

# %%
aapl
# Out:
#                   AAPL        lag1
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# 2010-01-08    7.570714    7.520714
# ...                ...         ...
# 2020-12-24  131.970001  130.960007
# 2020-12-28  136.690002  131.970001
# 2020-12-29  134.869995  136.690002
# 2020-12-30  133.720001  134.869995
# 2020-12-31  132.690002  133.720001
#
# [2769 rows x 2 columns]

# %%
aapl.AAPL.sub(aapl.lag1)
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05    0.013215
# 2010-01-06   -0.121786
# 2010-01-07   -0.013929
# 2010-01-08    0.050000
#                 ...
# 2020-12-24    1.009995
# 2020-12-28    4.720001
# 2020-12-29   -1.820007
# 2020-12-30   -1.149994
# 2020-12-31   -1.029999
# Length: 2769, dtype: float64

# %%
aapl["Diff"] = aapl.AAPL.sub(aapl.lag1)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff
# Date
# 2010-01-04    7.643214         NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000
# ...                ...         ...       ...
# 2020-12-24  131.970001  130.960007  1.009995
# 2020-12-28  136.690002  131.970001  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999
#
# [2769 rows x 3 columns]

# %%
aapl["%change"] = aapl.AAPL.div(aapl.lag1).sub(1).mul(100)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff   %change
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833
# ...                ...         ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265
#
# [2769 rows x 4 columns]

# %%
aapl["Diff2"] = aapl.AAPL.diff(periods=1)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff   %change     Diff2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000
# ...                ...         ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  1.009995
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -1.029999
#
# [2769 rows x 5 columns]

# %%
aapl["%change2"] = aapl.AAPL.pct_change(periods=1).mul(100)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff   %change     Diff2  %change2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000  0.664833
# ...                ...         ...       ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  1.009995  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  4.720001  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.820007 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -1.149994 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -1.029999 -0.770265
#
# [2769 rows x 6 columns]

# %%
del aapl["lag1"]

# %%
aapl
# Out:
#                   AAPL      Diff   %change     Diff2  %change2
# Date
# 2010-01-04    7.643214       NaN       NaN       NaN       NaN
# 2010-01-05    7.656429  0.013215  0.172893  0.013215  0.172893
# 2010-01-06    7.534643 -0.121786 -1.590632 -0.121786 -1.590632
# 2010-01-07    7.520714 -0.013929 -0.184871 -0.013929 -0.184871
# 2010-01-08    7.570714  0.050000  0.664833  0.050000  0.664833
# ...                ...       ...       ...       ...       ...
# 2020-12-24  131.970001  1.009995  0.771224  1.009995  0.771224
# 2020-12-28  136.690002  4.720001  3.576571  4.720001  3.576571
# 2020-12-29  134.869995 -1.820007 -1.331485 -1.820007 -1.331485
# 2020-12-30  133.720001 -1.149994 -0.852668 -1.149994 -0.852668
# 2020-12-31  132.690002 -1.029999 -0.770265 -1.029999 -0.770265
#
# [2769 rows x 5 columns]

# %%
aapl.rename(columns = {'%change2':'Change'}, inplace=True)

# %%
aapl
# Out:
#                   AAPL      Diff   %change     Diff2    Change
# Date
# 2010-01-04    7.643214       NaN       NaN       NaN       NaN
# 2010-01-05    7.656429  0.013215  0.172893  0.013215  0.172893
# 2010-01-06    7.534643 -0.121786 -1.590632 -0.121786 -1.590632
# 2010-01-07    7.520714 -0.013929 -0.184871 -0.013929 -0.184871
# 2010-01-08    7.570714  0.050000  0.664833  0.050000  0.664833
# ...                ...       ...       ...       ...       ...
# 2020-12-24  131.970001  1.009995  0.771224  1.009995  0.771224
# 2020-12-28  136.690002  4.720001  3.576571  4.720001  3.576571
# 2020-12-29  134.869995 -1.820007 -1.331485 -1.820007 -1.331485
# 2020-12-30  133.720001 -1.149994 -0.852668 -1.149994 -0.852668
# 2020-12-31  132.690002 -1.029999 -0.770265 -1.029999 -0.770265
#
# [2769 rows x 5 columns]

# %%
aapl.AAPL.resample("M").last()
#giving data at end of month
# Out:
# C:\Users\shaji\AppData\Local\Temp\ipykernel_16624\1741032415.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   aapl.AAPL.resample("M").last()
# Date
# 2010-01-31      6.859286
# 2010-02-28      7.307857
# 2010-03-31      8.392857
# 2010-04-30      9.324643
# 2010-05-31      9.174286
#                  ...
# 2020-08-31    129.039993
# 2020-09-30    115.809998
# 2020-10-31    108.860001
# 2020-11-30    119.050003
# 2020-12-31    132.690002
# Freq: ME, Name: AAPL, Length: 132, dtype: float64

# %%
aapl.AAPL.resample("BM").last()
#keeps out saturdays and sundays
# Out:
# C:\Users\shaji\AppData\Local\Temp\ipykernel_16624\2288930971.py:1: FutureWarning: 'BM' is deprecated and will be removed in a future version, please use 'BME' instead.
#   aapl.AAPL.resample("BM").last()
# Date
# 2010-01-29      6.859286
# 2010-02-26      7.307857
# 2010-03-31      8.392857
# 2010-04-30      9.324643
# 2010-05-31      9.174286
#                  ...
# 2020-08-31    129.039993
# 2020-09-30    115.809998
# 2020-10-30    108.860001
# 2020-11-30    119.050003
# 2020-12-31    132.690002
# Freq: BME, Name: AAPL, Length: 132, dtype: float64

# %%
aapl.AAPL.resample("BM").last().pct_change(periods=1).mul(100)
# Out:
# C:\Users\shaji\AppData\Local\Temp\ipykernel_16624\2117523069.py:1: FutureWarning: 'BM' is deprecated and will be removed in a future version, please use 'BME' instead.
#   aapl.AAPL.resample("BM").last().pct_change(periods=1).mul(100)
# Date
# 2010-01-29          NaN
# 2010-02-26     6.539620
# 2010-03-31    14.847028
# 2010-04-30    11.102138
# 2010-05-31    -1.612472
#                 ...
# 2020-08-31    21.437974
# 2020-09-30   -10.252632
# 2020-10-30    -6.001206
# 2020-11-30     9.360649
# 2020-12-31    11.457370
# Freq: BME, Name: AAPL, Length: 132, dtype: float64

# %%
aapl
# Out:
#                   AAPL      Diff   %change     Diff2    Change
# Date
# 2010-01-04    7.643214       NaN       NaN       NaN       NaN
# 2010-01-05    7.656429  0.013215  0.172893  0.013215  0.172893
# 2010-01-06    7.534643 -0.121786 -1.590632 -0.121786 -1.590632
# 2010-01-07    7.520714 -0.013929 -0.184871 -0.013929 -0.184871
# 2010-01-08    7.570714  0.050000  0.664833  0.050000  0.664833
# ...                ...       ...       ...       ...       ...
# 2020-12-24  131.970001  1.009995  0.771224  1.009995  0.771224
# 2020-12-28  136.690002  4.720001  3.576571  4.720001  3.576571
# 2020-12-29  134.869995 -1.820007 -1.331485 -1.820007 -1.331485
# 2020-12-30  133.720001 -1.149994 -0.852668 -1.149994 -0.852668
# 2020-12-31  132.690002 -1.029999 -0.770265 -1.029999 -0.770265
#
# [2769 rows x 5 columns]

# %%
ret = aapl.pct_change().dropna()
#dropna so that to drop Nan values

# %%
ret
# Out:
#                 AAPL       Diff    %change      Diff2     Change
# Date
# 2010-01-06 -0.015906 -10.216000 -10.200093 -10.216000 -10.200093
# 2010-01-07 -0.001849  -0.885624  -0.883775  -0.885624  -0.883775
# 2010-01-08  0.006648  -4.589552  -4.596201  -4.589552  -4.596201
# 2010-01-11 -0.008821  -2.335692  -2.326871  -2.335692  -2.326871
# 2010-01-12 -0.011375   0.278106   0.289481   0.278106   0.289481
# ...              ...        ...        ...        ...        ...
# 2020-12-24  0.007712  -2.097822  -2.105535  -2.097822  -2.105535
# 2020-12-28  0.035766   3.673294   3.637528   3.673294   3.637528
# 2020-12-29 -0.013315  -1.385595  -1.372280  -1.385595  -1.372280
# 2020-12-30 -0.008527  -0.368138  -0.359611  -0.368138  -0.359611
# 2020-12-31 -0.007703  -0.104344  -0.096641  -0.104344  -0.096641
#
# [2767 rows x 5 columns]

# %%
del ret["Diff"]
del ret["%change"]
del ret["Diff2"]
del ret["Change"]

# %%
ret.plot(kind="hist", figsize=(12,8), bins=100)
plt.show()

# %%
daily_mean_ret = ret.mean()
daily_mean_ret
# Out:
# AAPL    0.001191
# dtype: float64

# %%
var_daily = ret.var()
var_daily
# Out:
# AAPL    0.000318
# dtype: float64

# %%
std_daily = np.sqrt(var_daily)
std_daily
# Out:
# AAPL    0.017846
# dtype: float64

# %%
ret.std()
# Out:
# AAPL    0.017846
# dtype: float64

# %%
annual_mean_ret = daily_mean_ret*252
annual_mean_ret
#252 business days
# Out:
# AAPL    0.300085
# dtype: float64

# %%
annual_var_return = var_daily*252
annual_var_return
# Out:
# AAPL    0.080255
# dtype: float64

# %%
annual_std_return = np.sqrt(annual_var_return)
annual_std_return
# Out:
# AAPL    0.283293
# dtype: float64

# %%
ret.std()*np.sqrt(252)
# Out:
# AAPL    0.283293
# dtype: float64

# %%
ticker = ["SPY", "AAPL", "KO", "IBM", "DIS", "MSFT"]

# %%
stocks = yf.download(ticker, start = "2010-01-01", end = "2021-01-01")
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
close = stocks.loc[:,"Close"].copy()

# %%
normclose = close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret = close.pct_change().dropna()
ret.head()
# Out:
# Ticker          AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397

# %%
ret.describe()
# Out:
# Ticker         AAPL          DIS          IBM           KO         MSFT  \
# count   2768.000000  2768.000000  2768.000000  2768.000000  2768.000000
# mean       0.001191     0.000749     0.000082     0.000298     0.000841
# std        0.017843     0.015717     0.014132     0.011088     0.016012
# min       -0.128647    -0.129846    -0.128507    -0.096725    -0.147390
# 25%       -0.007123    -0.006210    -0.006321    -0.004698    -0.006939
# 50%        0.000903     0.000629     0.000287     0.000438     0.000654
# 75%        0.010379     0.007901     0.006743     0.005706     0.008636
# max        0.119808     0.144123     0.113010     0.064796     0.142169
#
# Ticker          SPY
# count   2768.000000
# mean       0.000491
# std        0.010909
# min       -0.109424
# 25%       -0.003532
# 50%        0.000637
# 75%        0.005421
# max        0.090603

# %%
ret.describe().T
# Out:
#          count      mean       std       min       25%       50%       75%  \
# Ticker
# AAPL    2768.0  0.001191  0.017843 -0.128647 -0.007123  0.000903  0.010379
# DIS     2768.0  0.000749  0.015717 -0.129846 -0.006210  0.000629  0.007901
# IBM     2768.0  0.000082  0.014132 -0.128507 -0.006321  0.000287  0.006743
# KO      2768.0  0.000298  0.011088 -0.096725 -0.004698  0.000438  0.005706
# MSFT    2768.0  0.000841  0.016012 -0.147390 -0.006939  0.000654  0.008636
# SPY     2768.0  0.000491  0.010909 -0.109424 -0.003532  0.000637  0.005421
#
#              max
# Ticker
# AAPL    0.119808
# DIS     0.144123
# IBM     0.113010
# KO      0.064796
# MSFT    0.142169
# SPY     0.090603

# %%
summary = ret.describe().T.loc[:,["mean","std"]]
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.001191  0.017843
# DIS     0.000749  0.015717
# IBM     0.000082  0.014132
# KO      0.000298  0.011088
# MSFT    0.000841  0.016012
# SPY     0.000491  0.010909

# %%
summary["mean"] = summary["mean"]*252
summary["std"] = summary["std"]*np.sqrt(252)
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.300134  0.283242
# DIS     0.188696  0.249504
# IBM     0.020648  0.224345
# KO      0.075091  0.176009
# MSFT    0.211915  0.254185
# SPY     0.123754  0.173170

# %%
summary.plot.scatter(x="std", y="mean", figsize=(12,8), s=50, fontsize=15)
for i in summary.index: #index implies rows number
    plt.annotate(i,xy=(summary.loc[i,"std"]+0.002, summary.loc[i,"mean"]+0.002),size=15)
plt.xlabel("Annual risk(std)", fontsize = 15)
plt.ylabel("Annual return", fontsize = 15)
plt.title("Risk/Return", fontsize = 35)
plt.grid()
plt.show()
#+0.002 so that the text displayed is off by some 0.002 from the data point

# %% [markdown]
# ## Correlation and Covariance

# %%
ret
# Out:
# Ticker          AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-24  0.007712  0.001037  0.006376  0.006782  0.007827  0.003890
# 2020-12-28  0.035766  0.029529  0.001043  0.013473  0.009921  0.008591
# 2020-12-29 -0.013315 -0.008722 -0.008172 -0.000554 -0.003601 -0.001908
# 2020-12-30 -0.008527  0.021827  0.004362  0.005727 -0.011019  0.001427
# 2020-12-31 -0.007703  0.000055  0.012385  0.007348  0.003338  0.005081
#
# [2768 rows x 6 columns]

# %%
ret.cov()
# Out:
# Ticker      AAPL       DIS       IBM        KO      MSFT       SPY
# Ticker
# AAPL    0.000318  0.000115  0.000110  0.000067  0.000158  0.000128
# DIS     0.000115  0.000247  0.000111  0.000085  0.000121  0.000121
# IBM     0.000110  0.000111  0.000200  0.000079  0.000121  0.000108
# KO      0.000067  0.000085  0.000079  0.000123  0.000076  0.000077
# MSFT    0.000158  0.000121  0.000121  0.000076  0.000256  0.000130
# SPY     0.000128  0.000121  0.000108  0.000077  0.000130  0.000119

# %%
ret.corr()
# Out:
# Ticker      AAPL       DIS       IBM        KO      MSFT       SPY
# Ticker
# AAPL    1.000000  0.408513  0.436100  0.339213  0.554051  0.659557
# DIS     0.408513  1.000000  0.497775  0.486514  0.480457  0.706726
# IBM     0.436100  0.497775  1.000000  0.502436  0.533130  0.703342
# KO      0.339213  0.486514  0.502436  1.000000  0.429749  0.639324
# MSFT    0.554051  0.480457  0.533130  0.429749  1.000000  0.744601
# SPY     0.659557  0.706726  0.703342  0.639324  0.744601  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(),cmap="Reds",annot=True,annot_kws={"size":15},vmax=1)
plt.show()

# %% [markdown]
# # Simple returns and log returns

# %%
df = pd.DataFrame(index=[2016,2017,2018],data=[100,50,95],columns=["Price"])

# %%
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
simplereturns = df.pct_change().dropna()
simplereturns
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %%
simplereturns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
#Mean returns are misleading cuz clearly price has gone down from 100 to 95 but mean returns is 0.2

# %%
logreturns = np.log(df/df.shift(1)).dropna()
logreturns
# Out:
#          Price
# 2017 -0.693147
# 2018  0.641854

# %%
logreturns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(logreturns.mean()*2)
# Out:
# Price    95.0
# dtype: float64

# %%
SPY = yf.download("SPY")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
spy = SPY.Close

# %%
spy
# Out:
# Date
# 1993-01-29     43.937500
# 1993-02-01     44.250000
# 1993-02-02     44.343750
# 1993-02-03     44.812500
# 1993-02-04     45.000000
#                  ...
# 2024-06-27    546.369995
# 2024-06-28    544.219971
# 2024-07-01    545.340027
# 2024-07-02    549.010010
# 2024-07-03    551.460022
# Name: Close, Length: 7913, dtype: float64

# %%
spy = SPY.Close.to_frame()

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2024-06-27  546.369995
# 2024-06-28  544.219971
# 2024-07-01  545.340027
# 2024-07-02  549.010010
# 2024-07-03  551.460022
#
# [7913 rows x 1 columns]

# %%
spy.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize = 15)
plt.show()

# %%
spy_roll = spy.rolling(window=10)

# %%
spy_roll = spy_roll.mean()

# %%
spy_roll.head(15)
# Out:
#                 Close
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04        NaN
# 1993-02-05        NaN
# 1993-02-08        NaN
# 1993-02-09        NaN
# 1993-02-10        NaN
# 1993-02-11  44.659375
# 1993-02-12  44.725000
# 1993-02-16  44.646875
# 1993-02-17  44.556250
# 1993-02-18  44.415625
# 1993-02-19  44.271875

# %%
spy.rolling(window=10).median()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2024-06-27  545.170013
# 2024-06-28  545.170013
# 2024-07-01  545.425018
# 2024-07-02  545.425018
# 2024-07-03  545.425018
#
# [7913 rows x 1 columns]

# %%
spy.rolling(window=10).max()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2024-06-27  548.489990
# 2024-06-28  548.489990
# 2024-07-01  548.489990
# 2024-07-02  549.010010
# 2024-07-03  551.460022
#
# [7913 rows x 1 columns]

# %%
spy.rolling(window=10, min_periods=5).max().head(15)
# Out:
#                Close
# Date
# 1993-01-29       NaN
# 1993-02-01       NaN
# 1993-02-02       NaN
# 1993-02-03       NaN
# 1993-02-04  45.00000
# 1993-02-05  45.00000
# 1993-02-08  45.00000
# 1993-02-09  45.00000
# 1993-02-10  45.00000
# 1993-02-11  45.00000
# 1993-02-12  45.00000
# 1993-02-16  45.00000
# 1993-02-17  45.00000
# 1993-02-18  45.00000
# 1993-02-19  44.96875

# %%
spy["SMA50"] = spy.rolling(window=50,min_periods=50).mean()

# %%
spy.head(50)
# Out:
#                Close    SMA50
# Date
# 1993-01-29  43.93750      NaN
# 1993-02-01  44.25000      NaN
# 1993-02-02  44.34375      NaN
# 1993-02-03  44.81250      NaN
# 1993-02-04  45.00000      NaN
# 1993-02-05  44.96875      NaN
# 1993-02-08  44.96875      NaN
# 1993-02-09  44.65625      NaN
# 1993-02-10  44.71875      NaN
# 1993-02-11  44.93750      NaN
# 1993-02-12  44.59375      NaN
# 1993-02-16  43.46875      NaN
# 1993-02-17  43.43750      NaN
# 1993-02-18  43.40625      NaN
# 1993-02-19  43.56250      NaN
# 1993-02-22  43.71875      NaN
# 1993-02-23  43.68750      NaN
# 1993-02-24  44.25000      NaN
# 1993-02-25  44.34375      NaN
# 1993-02-26  44.40625      NaN
# 1993-03-01  44.28125      NaN
# 1993-03-02  44.93750      NaN
# 1993-03-03  45.12500      NaN
# 1993-03-04  44.87500      NaN
# 1993-03-05  44.75000      NaN
# 1993-03-08  45.75000      NaN
# 1993-03-09  45.59375      NaN
# 1993-03-10  45.68750      NaN
# 1993-03-11  45.56250      NaN
# 1993-03-12  45.09375      NaN
# ...

# %%
spy
# Out:
#                  Close       SMA50
# Date
# 1993-01-29   43.937500         NaN
# 1993-02-01   44.250000         NaN
# 1993-02-02   44.343750         NaN
# 1993-02-03   44.812500         NaN
# 1993-02-04   45.000000         NaN
# ...                ...         ...
# 2024-06-27  546.369995  524.966600
# 2024-06-28  544.219971  525.839999
# 2024-07-01  545.340027  526.756400
# 2024-07-02  549.010010  527.833400
# 2024-07-03  551.460022  528.868201
#
# [7913 rows x 2 columns]

# %%
spy.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy["SMA200"] = spy.Close.rolling(window=200,min_periods=200).mean() #here spy.Close since i had added sma50 column i should specify which column to use
spy.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy["EMA100"] = spy.Close.ewm(span=100,min_periods=100).mean()
#EMA - Exponential Moving Averages

# %%
spy
# Out:
#                  Close       SMA50      SMA200      EMA100
# Date
# 1993-01-29   43.937500         NaN         NaN         NaN
# 1993-02-01   44.250000         NaN         NaN         NaN
# 1993-02-02   44.343750         NaN         NaN         NaN
# 1993-02-03   44.812500         NaN         NaN         NaN
# 1993-02-04   45.000000         NaN         NaN         NaN
# ...                ...         ...         ...         ...
# 2024-06-27  546.369995  524.966600  484.877200  515.681975
# 2024-06-28  544.219971  525.839999  485.368350  516.247084
# 2024-07-01  545.340027  526.756400  485.862500  516.823182
# 2024-07-02  549.010010  527.833400  486.355750  517.460545
# 2024-07-03  551.460022  528.868201  486.896201  518.133802
#
# [7913 rows x 4 columns]

# %%
spy.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy["Day"] = spy.index.day_name()

# %%
spy["Quarter"] = spy.index.quarter

# %%
SPY = yf.download("SPY")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
spy=SPY.Close.to_frame()

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2024-06-27  546.369995
# 2024-06-28  544.219971
# 2024-07-01  545.340027
# 2024-07-02  549.010010
# 2024-07-03  551.460022
#
# [7913 rows x 1 columns]

# %%
all_days = pd.date_range(start="2010-12-31", end="2020-01-01", freq="D")
all_days
# Out:
# DatetimeIndex(['2010-12-31', '2011-01-01', '2011-01-02', '2011-01-03',
#                '2011-01-04', '2011-01-05', '2011-01-06', '2011-01-07',
#                '2011-01-08', '2011-01-09',
#                ...
#                '2019-12-23', '2019-12-24', '2019-12-25', '2019-12-26',
#                '2019-12-27', '2019-12-28', '2019-12-29', '2019-12-30',
#                '2019-12-31', '2020-01-01'],
#               dtype='datetime64[ns]', length=3289, freq='D')

# %%
spy = spy.reindex(all_days)

# %%
spy
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01         NaN
# 2011-01-02         NaN
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2019-12-28         NaN
# 2019-12-29         NaN
# 2019-12-30  321.079987
# 2019-12-31  321.859985
# 2020-01-01         NaN
#
# [3289 rows x 1 columns]

# %%
spy.ffill()
#fill NaN values with prev value
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01  125.750000
# 2011-01-02  125.750000
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2019-12-28  322.859985
# 2019-12-29  322.859985
# 2019-12-30  321.079987
# 2019-12-31  321.859985
# 2020-01-01  321.859985
#
# [3289 rows x 1 columns]

# %%
spy.bfill()
#fill NaN values with next value
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01  127.050003
# 2011-01-02  127.050003
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2019-12-28  321.079987
# 2019-12-29  321.079987
# 2019-12-30  321.079987
# 2019-12-31  321.859985
# 2020-01-01         NaN
#
# [3289 rows x 1 columns]

# %%
SPY = yf.download("SPY", interval="1wk")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
SPY
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-25   43.968750   43.968750   43.750000   43.937500   24.684109
# 1993-02-01   43.968750   45.093750   43.968750   44.968750   25.263460
# 1993-02-08   44.968750   45.125000   44.531250   44.593750   25.052776
# 1993-02-15   44.468750   44.468750   42.812500   43.562500   24.473436
# 1993-02-22   43.687500   44.437500   43.468750   44.406250   24.947449
# ...                ...         ...         ...         ...         ...
# 2024-06-03  529.020020  536.890015  522.599976  534.010010  532.292786
# 2024-06-10  533.179993  544.119995  532.049988  542.780029  541.034607
# 2024-06-17  542.080017  550.119995  541.609985  544.510010  542.759033
# 2024-06-24  544.330017  550.280029  542.440002  544.219971  544.219971
# 2024-07-01  545.630005  551.830017  542.520020  551.460022  551.460022
#
#                Volume
# Date
# 1993-01-25    1003200
# 1993-02-01    2234800
# 1993-02-08    1159800
# ...

# %% [markdown]
# ## Cummaltive Returns, Drawdowns etc..

# %%
apple = yf.download("AAPL")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
apple = apple.Close.to_frame()

# %%
apple
# Out:
#                  Close
# Date
# 1980-12-12    0.128348
# 1980-12-15    0.121652
# 1980-12-16    0.112723
# 1980-12-17    0.115513
# 1980-12-18    0.118862
# ...                ...
# 2024-06-27  214.100006
# 2024-06-28  210.619995
# 2024-07-01  216.750000
# 2024-07-02  220.270004
# 2024-07-03  221.550003
#
# [10980 rows x 1 columns]

# %%
apple["d_returns"] = np.log(apple/apple.shift(1))

# %%
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-12    0.128348        NaN
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# ...                ...        ...
# 2024-06-27  214.100006   0.003978
# 2024-06-28  210.619995  -0.016388
# 2024-07-01  216.750000   0.028689
# 2024-07-02  220.270004   0.016109
# 2024-07-03  221.550003   0.005794
#
# [10980 rows x 2 columns]

# %%
apple.dropna(inplace=True)

# %%
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# 1980-12-19    0.126116   0.059239
# ...                ...        ...
# 2024-06-27  214.100006   0.003978
# 2024-06-28  210.619995  -0.016388
# 2024-07-01  216.750000   0.028689
# 2024-07-02  220.270004   0.016109
# 2024-07-03  221.550003   0.005794
#
# [10979 rows x 2 columns]

# %%
apple.d_returns.sum()
# Out:
# 7.453658320939841

# %%
invested_amount = 1
curr_val = np.exp(apple.d_returns.sum())*invested_amount
curr_val
# Out:
# 1726.16647951399

# %%
apple["cummreturns"] = apple.d_returns.cumsum().apply(np.exp)*invested_amount

# %%
apple
# Out:
#                  Close  d_returns  cummreturns
# Date
# 1980-12-15    0.121652  -0.053581     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261
# 1980-12-17    0.115513   0.024450     0.899998
# 1980-12-18    0.118862   0.028580     0.926092
# 1980-12-19    0.126116   0.059239     0.982610
# ...                ...        ...          ...
# 2024-06-27  214.100006   0.003978  1668.121186
# 2024-06-28  210.619995  -0.016388  1641.007314
# 2024-07-01  216.750000   0.028689  1688.768130
# 2024-07-02  220.270004   0.016109  1716.193602
# 2024-07-03  221.550003   0.005794  1726.166480
#
# [10979 rows x 3 columns]

# %%
apple.cummreturns.plot(figsize=(12,8), title="APPLE Buy and Hold", fontsize=12)
plt.ylabel("Current Value", fontsize=14)
plt.show()

# %%
apple.d_returns.mean()*252
# Out:
# 0.17108314936486382

# %%
apple.d_returns.std()*np.sqrt(252)
# Out:
# 0.44972169949468627

# %%
# how to calculate drawdowns
apple["cummax"] = apple.cummreturns.cummax()

# %%
apple
# Out:
#                  Close  d_returns  cummreturns       cummax
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829
# 1980-12-17    0.115513   0.024450     0.899998     0.947829
# 1980-12-18    0.118862   0.028580     0.926092     0.947829
# 1980-12-19    0.126116   0.059239     0.982610     0.982610
# ...                ...        ...          ...          ...
# 2024-06-27  214.100006   0.003978  1668.121186  1688.144811
# 2024-06-28  210.619995  -0.016388  1641.007314  1688.144811
# 2024-07-01  216.750000   0.028689  1688.768130  1688.768130
# 2024-07-02  220.270004   0.016109  1716.193602  1716.193602
# 2024-07-03  221.550003   0.005794  1726.166480  1726.166480
#
# [10979 rows x 4 columns]

# %%
apple[["cummreturns", "cummax"]].plot(figsize=(12,8), title="APPLE Buy and Hold + Cummax", fontsize=12)
plt.ylabel("Current Value", fontsize=14)
plt.show()

# %%
apple["drawdown"] = apple["cummax"]-apple["cummreturns"]

# %%
apple
# Out:
#                  Close  d_returns  cummreturns       cummax   drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829   0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829   0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829   0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829   0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610   0.000000
# ...                ...        ...          ...          ...        ...
# 2024-06-27  214.100006   0.003978  1668.121186  1688.144811  20.023625
# 2024-06-28  210.619995  -0.016388  1641.007314  1688.144811  47.137496
# 2024-07-01  216.750000   0.028689  1688.768130  1688.768130   0.000000
# 2024-07-02  220.270004   0.016109  1716.193602  1716.193602   0.000000
# 2024-07-03  221.550003   0.005794  1726.166480  1726.166480   0.000000
#
# [10979 rows x 5 columns]

# %%
apple.drawdown.max()
# Out:
# 444.02718404402026

# %%
apple.drawdown.idxmax()
#for getting st what date the drawdown was max
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
apple.loc[apple.index=="2023-01-05"]
# Out:
#                  Close  d_returns  cummreturns       cummax    drawdown
# Date
# 2023-01-05  125.019997  -0.010661   974.070524  1418.097708  444.027184

# %%
apple.loc[apple.index<="2023-01-05"]
# Out:
#                  Close  d_returns  cummreturns       cummax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2022-12-29  129.610001   0.027931  1009.832703  1418.097708  408.265004
# 2022-12-30  129.929993   0.002466  1012.325863  1418.097708  405.771845
# 2023-01-03  125.070000  -0.038122   974.460113  1418.097708  443.637594
# 2023-01-04  126.360001   0.010261   984.510920  1418.097708  433.586787
# 2023-01-05  125.019997  -0.010661   974.070524  1418.097708  444.027184
#
# [10605 rows x 5 columns]

# %%
apple["drawdown%"] = (apple["cummax"]-apple["cummreturns"])/apple["cummax"]

# %%
apple
# Out:
#                  Close  d_returns  cummreturns       cummax   drawdown  \
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829   0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829   0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829   0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829   0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610   0.000000
# ...                ...        ...          ...          ...        ...
# 2024-06-27  214.100006   0.003978  1668.121186  1688.144811  20.023625
# 2024-06-28  210.619995  -0.016388  1641.007314  1688.144811  47.137496
# 2024-07-01  216.750000   0.028689  1688.768130  1688.768130   0.000000
# 2024-07-02  220.270004   0.016109  1716.193602  1716.193602   0.000000
# 2024-07-03  221.550003   0.005794  1726.166480  1726.166480   0.000000
#
#             drawdown%
# Date
# 1980-12-15   0.000000
# 1980-12-16   0.073398
# 1980-12-17   0.050464
# ...

# %%
apple["drawdown%"].max()
# Out:
# 0.82216567924191

# %%
apple["drawdown%"].idxmax()
# Out:
# Timestamp('1997-12-23 00:00:00')

# %%
apple.loc[apple.index<="1997-12-23"]
# Out:
#                Close  d_returns  cummreturns    cummax  drawdown  drawdown%
# Date
# 1980-12-15  0.121652  -0.053581     0.947829  0.947829  0.000000   0.000000
# 1980-12-16  0.112723  -0.076231     0.878261  0.947829  0.069569   0.073398
# 1980-12-17  0.115513   0.024450     0.899998  0.947829  0.047831   0.050464
# 1980-12-18  0.118862   0.028580     0.926092  0.947829  0.021738   0.022934
# 1980-12-19  0.126116   0.059239     0.982610  0.982610  0.000000   0.000000
# ...              ...        ...          ...       ...       ...        ...
# 1997-12-17  0.124442  -0.026549     0.969567  5.060882  4.091315   0.808419
# 1997-12-18  0.123326  -0.009008     0.960872  5.060882  4.100010   0.810137
# 1997-12-19  0.122210  -0.009090     0.952177  5.060882  4.108705   0.811856
# 1997-12-22  0.118862  -0.027778     0.926092  5.060882  4.134790   0.817010
# 1997-12-23  0.115513  -0.028580     0.899998  5.060882  4.160883   0.822166
#
# [4306 rows x 6 columns]

# %% [markdown]
# ## SMA STRATEGY

# %%
data = apple.Close.loc[apple.index>="1991-01-01"]

# %%
data = data.to_frame()

# %%
data
# Out:
#                  Close
# Date
# 1991-01-02    0.388393
# 1991-01-03    0.383929
# 1991-01-04    0.386161
# 1991-01-07    0.386161
# 1991-01-08    0.386161
# ...                ...
# 2024-06-27  214.100006
# 2024-06-28  210.619995
# 2024-07-01  216.750000
# 2024-07-02  220.270004
# 2024-07-03  221.550003
#
# [8439 rows x 1 columns]

# %%
sma_s = 50
sma_l = 100

# %%
data["sma_s"] = data.rolling(sma_s).mean()
data
# Out:
#                  Close     sma_s
# Date
# 1991-01-02    0.388393       NaN
# 1991-01-03    0.383929       NaN
# 1991-01-04    0.386161       NaN
# 1991-01-07    0.386161       NaN
# 1991-01-08    0.386161       NaN
# ...                ...       ...
# 2024-06-27  214.100006  189.8298
# 2024-06-28  210.619995  190.6822
# 2024-07-01  216.750000  191.6764
# 2024-07-02  220.270004  192.7818
# 2024-07-03  221.550003  193.8960
#
# [8439 rows x 2 columns]

# %%
data["sma_l"] = data.Close.rolling(sma_l).mean()

# %%
data
# Out:
#                  Close     sma_s     sma_l
# Date
# 1991-01-02    0.388393       NaN       NaN
# 1991-01-03    0.383929       NaN       NaN
# 1991-01-04    0.386161       NaN       NaN
# 1991-01-07    0.386161       NaN       NaN
# 1991-01-08    0.386161       NaN       NaN
# ...                ...       ...       ...
# 2024-06-27  214.100006  189.8298  183.1470
# 2024-06-28  210.619995  190.6822  183.3764
# 2024-07-01  216.750000  191.6764  183.6509
# 2024-07-02  220.270004  192.7818  183.9595
# 2024-07-03  221.550003  193.8960  184.2918
#
# [8439 rows x 3 columns]

# %%
data.plot(figsize=(12,8), title="AAPL-SMA{} | SMA{}".format(sma_s,sma_l),fontsize=12)
# Out:
# <Axes: title={'center': 'AAPL-SMA50 | SMA100'}, xlabel='Date'>

# %%
data.loc["2016"].plot(figsize=(12,8), title="AAPL-SMA{} | SMA{}".format(sma_s,sma_l),fontsize=12)
# Out:
# <Axes: title={'center': 'AAPL-SMA50 | SMA100'}, xlabel='Date'>

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-05-23    0.402902    0.534420    0.513326
# 1991-05-24    0.409598    0.530960    0.513538
# 1991-05-28    0.410714    0.527344    0.513806
# 1991-05-29    0.419643    0.523638    0.514141
# 1991-05-30    0.425223    0.519732    0.514531
# ...                ...         ...         ...
# 2024-06-27  214.100006  189.829800  183.147000
# 2024-06-28  210.619995  190.682200  183.376400
# 2024-07-01  216.750000  191.676400  183.650900
# 2024-07-02  220.270004  192.781800  183.959500
# 2024-07-03  221.550003  193.896000  184.291800
#
# [8340 rows x 3 columns]

# %%
data["position"] = np.where(data["sma_s"]>data["sma_l"],1,-1)
#we go long if sma_s>sma_l as indicated by 1 and go short if otherwise as indicated by -1

# %%
data
# Out:
#                  Close       sma_s       sma_l  position
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1
# 1991-05-24    0.409598    0.530960    0.513538         1
# 1991-05-28    0.410714    0.527344    0.513806         1
# 1991-05-29    0.419643    0.523638    0.514141         1
# 1991-05-30    0.425223    0.519732    0.514531         1
# ...                ...         ...         ...       ...
# 2024-06-27  214.100006  189.829800  183.147000         1
# 2024-06-28  210.619995  190.682200  183.376400         1
# 2024-07-01  216.750000  191.676400  183.650900         1
# 2024-07-02  220.270004  192.781800  183.959500         1
# 2024-07-03  221.550003  193.896000  184.291800         1
#
# [8340 rows x 4 columns]

# %%
data.loc[:,["sma_s", "sma_l", "position"]].plot(figsize=(12,8), title="AAPL-SMA{} | SMA{}".format(sma_s,sma_l),fontsize=12)
# Out:
# <Axes: title={'center': 'AAPL-SMA50 | SMA100'}, xlabel='Date'>

# %%
data.loc["2016",["sma_s", "sma_l", "position"]].plot(figsize=(12,8), title="AAPL-SMA{} | SMA{}".format(sma_s,sma_l),fontsize=12, secondary_y="position")
#did this as position value is too small
# Out:
# <Axes: title={'center': 'AAPL-SMA50 | SMA100'}, xlabel='Date'>

# %%
data["returnsb&h"] = np.log(data.Close.div(data.Close.shift(1)))

# %%
data["strategy"] = data["returnsb&h"]*data.position.shift(1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  strategy
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1         NaN       NaN
# 1991-05-24    0.409598    0.530960    0.513538         1    0.016483  0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721  0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507  0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209  0.013209
# ...                ...         ...         ...       ...         ...       ...
# 2024-06-27  214.100006  189.829800  183.147000         1    0.003978  0.003978
# 2024-06-28  210.619995  190.682200  183.376400         1   -0.016388 -0.016388
# 2024-07-01  216.750000  191.676400  183.650900         1    0.028689  0.028689
# 2024-07-02  220.270004  192.781800  183.959500         1    0.016109  0.016109
# 2024-07-03  221.550003  193.896000  184.291800         1    0.005794  0.005794
#
# ...

# %%
data.dropna(inplace=True)

# %%
data[["returnsb&h", "strategy"]].sum()
# Out:
# returnsb&h    6.309710
# strategy      1.657329
# dtype: float64

# %%
data[["returnsb&h", "strategy"]].sum().apply(np.exp)
# what 1$ investment would give us
# Out:
# returnsb&h    549.885578
# strategy        5.245283
# dtype: float64

# %%
data[["returnsb&h", "strategy"]].std()*np.sqrt(252)
# annual std
# Out:
# returnsb&h    0.432664
# strategy      0.432819
# dtype: float64

# %%
#Clearly our strategy isnt good for this stock. Maybe we need to change our strategy

# %%
data.Close.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Strategy adjusted with long bias
#
#
# Adjusting a trading strategy with a "long bias" typically means modifying the strategy to favor long positions more heavily than short positions. In a long-biased strategy, an investor or trader is more inclined to buy (go long) assets, expecting their prices to rise, rather than sell (go short) them, expecting their prices to fall.

# %%
data["position2"] = np.where(data["sma_s"]>data["sma_l"],1,0)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  \
# Date
# 1991-05-24    0.409598    0.530960    0.513538         1    0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209
# 1991-05-31    0.419643    0.516027    0.514866         1   -0.013209
# ...                ...         ...         ...       ...         ...
# 2024-06-27  214.100006  189.829800  183.147000         1    0.003978
# 2024-06-28  210.619995  190.682200  183.376400         1   -0.016388
# 2024-07-01  216.750000  191.676400  183.650900         1    0.028689
# 2024-07-02  220.270004  192.781800  183.959500         1    0.016109
# 2024-07-03  221.550003  193.896000  184.291800         1    0.005794
#
#             strategy  position2
# Date
# 1991-05-24  0.016483          1
# 1991-05-28  0.002721          1
# ...

# %%
data["strategy2"] = data["returnsb&h"]*data.position2.shift(1)

# %%
data.dropna(inplace=True)

# %%
data[["returnsb&h", "strategy2"]].sum()
# Out:
# returnsb&h    6.293227
# strategy2     3.967037
# dtype: float64

# %%
data[["returnsb&h", "strategy2"]].sum().apply(np.exp)
# what 1$ will be
# Out:
# returnsb&h    540.896213
# strategy2      52.827767
# dtype: float64

# %%
data[["returnsb&h", "strategy2"]].std()*np.sqrt(252)
# Out:
# returnsb&h    0.432681
# strategy2     0.334123
# dtype: float64

# %%
## Strategy 2 is better than buy and hold

# %% [markdown]
# ## Creating our first function

# %%
def test_strategy(stock, start, end, SMA):
    df = yf.download(stock, start=start, end=end)
    data = df.Close.to_frame()
    data["returns"] = np.log(data.Close.div(data.Close.shift(1)))
    data["SMA_S"] = data.Close.rolling(int(SMA[0])).mean()
    data["SMA_L"] = data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)

    data["position"] = np.where(data["SMA_S"]>data["SMA_L"],1,-1)
    data["strategy"] = data["returns"]*data["position"].shift(1)
    data.dropna(inplace=True)
    ret = np.exp(data["strategy"].sum())
    std = data["strategy"].std()*np.sqrt(252)
    return ret,std

# %%
test_strategy("SPY", "2000-01-01", "2020-01-01", (50,200))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# (4.766371508372407, 0.18787947185958592)

# %% [markdown]
# ## Creating our first class

# %%
class SMABacktester():
    def __init__(self,symbol,SMA_S,SMA_L,start,end):
        self.symbol = symbol
        self.SMA_S = SMA_S
        self.SMA_L = SMA_L
        self.start = start
        self.end = end
        self.result = None
        self.get_data()
        
    def get_data(self):
        df = yf.download(self.symbol, start=self.start, end=self.end)
        data = df.Close.to_frame()
        data["returns"] = np.log(data.Close.div(data.Close.shift(1)))
        data["SMA_S"] = data.Close.rolling(self.SMA_S).mean()
        data["SMA_L"] = data.Close.rolling(self.SMA_L).mean()
        data.dropna(inplace=True)
        self.data2 = data

        return data

    def test_results(self):
        data = self.data2.copy().dropna()
        data["position"] = np.where(data["SMA_S"]>data["SMA_L"],1,-1)
        data["strategy"] = data["returns"]*data["position"].shift(1)
        data.dropna(inplace=True)
        data["returnsbh"] = data["returns"].cumsum().apply(np.exp)
        data["returnsstrategy"] = data["strategy"].cumsum().apply(np.exp)
        perf = data["returnsstrategy"].iloc[-1]
        outperf = perf-data["returnsbh"].iloc[-1]
        self.results = data
        
        ret = np.exp(data["strategy"].sum())
        std = data["strategy"].std()*np.sqrt(252)

        #return ret, std
        return round(perf,6), round(outperf,6)

    def plot_results(self):
        if self.results is None:
            print("Run the test please")
        else:
            title = "{}| SMA_S = {} | SMA_L{}".format(self.symbol,self.SMA_S, self.SMA_L)
            self.results[["returnsbh","returnsstrategy"]].plot(title=title, figsize=(12,8))

# %%
tester = SMABacktester("SPY", 50, 100, "2000-01-01", "2020-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (2.592726, 0.297824)

# %%
tester.plot_results()
